# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
doc = pd.read_excel("C:/Users/STAFF/Desktop/Git_Repos/Telco_customer_churn.xlsx")
doc.sample(5)
# Out:
#       CustomerID  Count        Country       State              City  \
# 1017  5089-IFSDP      1  United States  California  Huntington Beach
# 5544  5236-XMZJY      1  United States  California       Los Angeles
# 6220  9500-WBGRP      1  United States  California          Danville
# 4641  8617-ENBDS      1  United States  California         Helendale
# 915   7587-RZNME      1  United States  California          Valencia
#
#       Zip Code                Lat Long   Latitude   Longitude  Gender  ...  \
# 1017     92647  33.723579, -118.005441  33.723579 -118.005441  Female  ...
# 5544     90031  34.085807, -118.206617  34.085807 -118.206617  Female  ...
# 6220     94526  37.815459, -121.977203  37.815459 -121.977203    Male  ...
# 4641     92342   34.757783, -117.33997  34.757783 -117.339970    Male  ...
# 915      91355   34.43987, -118.644609  34.439870 -118.644609    Male  ...
#
#             Contract Paperless Billing             Payment Method  \
# 1017        Two year               Yes  Bank transfer (automatic)
# 5544  Month-to-month                No  Bank transfer (automatic)
# 6220        Two year               Yes               Mailed check
# 4641  Month-to-month               Yes    Credit card (automatic)
# 915   Month-to-month               Yes           Electronic check
#
#       Monthly Charges Total Charges Churn Label Churn Value Churn Score  CLTV  \
# 1017           109.45       6144.55         Yes           1          89  6424
# 5544            59.65       2536.55          No           0          80  3048
# 6220            19.10       1268.85          No           0          31  4535
# 4641            73.60         232.5          No           0          53  5510
# 915             43.30        123.65         Yes           1          91  4849
#
#                                   Churn Reason
# 1017                   Product dissatisfaction
# 5544                                       NaN
# 6220                                       NaN
# 4641                                       NaN
# 915   Lack of affordable download/upload speed
#
# [5 rows x 33 columns]

# %%
doc.drop(columns =["CustomerID","Count","Churn Reason","Churn Label","Churn Score","Lat Long"], inplace = True)

# %%
doc.shape
# Out:
# (7043, 27)

# %%
doc = doc.dropna()
doc.shape
# Out:
# (7043, 27)

# %%
doc = doc[doc["Total Charges"] != " "]
doc.shape
# Out:
# (7032, 27)

# %%
doc["Total Charges"] = pd.to_numeric(doc["Total Charges"])

# %%
doc.dtypes
# Out:
# Country               object
# State                 object
# City                  object
# Zip Code               int64
# Latitude             float64
# Longitude            float64
# Gender                object
# Senior Citizen        object
# Partner               object
# Dependents            object
# Tenure Months          int64
# Phone Service         object
# Multiple Lines        object
# Internet Service      object
# Online Security       object
# Online Backup         object
# Device Protection     object
# Tech Support          object
# Streaming TV          object
# Streaming Movies      object
# Contract              object
# Paperless Billing     object
# Payment Method        object
# Monthly Charges      float64
# Total Charges        float64
# Churn Value            int64
# CLTV                   int64
# dtype: object

# %%
def values_in_each_col(dataframe):
    for i in dataframe:
        if dataframe[i].dtypes == "object":
            print(f"{i} : {dataframe[i].unique()}")

# %%
values_in_each_col(doc)
# Out:
# Country : ['United States']
# State : ['California']
# City : ['Los Angeles' 'Beverly Hills' 'Huntington Park' ... 'Tulelake'
#  'Olympic Valley' 'Redcrest']
# Gender : ['Male' 'Female']
# Senior Citizen : ['No' 'Yes']
# Partner : ['No' 'Yes']
# Dependents : ['No' 'Yes']
# Phone Service : ['Yes' 'No']
# Multiple Lines : ['No' 'Yes' 'No phone service']
# Internet Service : ['DSL' 'Fiber optic' 'No']
# Online Security : ['Yes' 'No' 'No internet service']
# Online Backup : ['Yes' 'No' 'No internet service']
# Device Protection : ['No' 'Yes' 'No internet service']
# Tech Support : ['No' 'Yes' 'No internet service']
# Streaming TV : ['No' 'Yes' 'No internet service']
# Streaming Movies : ['No' 'Yes' 'No internet service']
# Contract : ['Month-to-month' 'Two year' 'One year']
# Paperless Billing : ['Yes' 'No']
# Payment Method : ['Mailed check' 'Electronic check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']

# %%
doc.replace("No internet service" , "No", inplace = True)
doc.replace("No phone service" , "No", inplace = True)

# %%
values_in_each_col(doc)
# Out:
# Country : ['United States']
# State : ['California']
# City : ['Los Angeles' 'Beverly Hills' 'Huntington Park' ... 'Tulelake'
#  'Olympic Valley' 'Redcrest']
# Gender : ['Male' 'Female']
# Senior Citizen : ['No' 'Yes']
# Partner : ['No' 'Yes']
# Dependents : ['No' 'Yes']
# Phone Service : ['Yes' 'No']
# Multiple Lines : ['No' 'Yes']
# Internet Service : ['DSL' 'Fiber optic' 'No']
# Online Security : ['Yes' 'No']
# Online Backup : ['Yes' 'No']
# Device Protection : ['No' 'Yes']
# Tech Support : ['No' 'Yes']
# Streaming TV : ['No' 'Yes']
# Streaming Movies : ['No' 'Yes']
# Contract : ['Month-to-month' 'Two year' 'One year']
# Paperless Billing : ['Yes' 'No']
# Payment Method : ['Mailed check' 'Electronic check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

for i in doc.columns:
    if doc[i].dtypes == "object":
         doc[i] = encoder.fit_transform(doc[i])

doc.sample(5)
# Out:
#       Country  State  City  Zip Code   Latitude   Longitude  Gender  \
# 2644        0      0   222     94925  37.924014 -122.511694       0
# 1541        0      0   799     94028  37.369709 -122.215844       1
# 4579        0      0   869     92114  32.707892 -117.055120       0
# 956         0      0   869     92113  32.697098 -117.116587       0
# 2249        0      0   647     92555  33.907361 -117.109972       1
#
#       Senior Citizen  Partner  Dependents  ...  Tech Support  Streaming TV  \
# 2644               0        1           1  ...             0             1
# 1541               1        0           0  ...             0             1
# 4579               1        1           1  ...             0             1
# 956                0        1           0  ...             0             1
# 2249               0        0           0  ...             0             1
#
#       Streaming Movies  Contract  Paperless Billing  Payment Method  \
# 2644                 1         0                  1               0
# 1541                 1         1                  1               2
# 4579                 1         2                  1               2
# 956                  0         0                  1               0
# 2249                 1         0                  1               2
#
#       Monthly Charges  Total Charges  Churn Value  CLTV
# 2644            99.30        4209.95            0  3280
# 1541            45.25        3264.45            1  5824
# 4579            96.55        2263.45            0  4309
# 956             84.40        4116.15            1  5135
# 2249           106.45        6300.15            0  4842
#
# [5 rows x 27 columns]

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
minmax = MinMaxScaler()

# doc = minmax.fit_transform(doc.values)


doc.iloc[:, :] = minmax.fit_transform(doc.values)

doc = pd.DataFrame(doc) 
doc.sample(5)
# Out:
#       Country  State      City  Zip Code  Latitude  Longitude  Gender  \
# 2010        0      0  0.115248  0.211201  0.167444   0.555763       0
# 4891        0      0  0.292553  0.588149  0.408441   0.413659       1
# 5968        0      0  0.194149  0.467695  0.134331   0.662925       0
# 3519        0      0  0.315603  0.459578  0.139533   0.630396       0
# 6734        0      0  0.498227  0.001948  0.158278   0.599592       0
#
#       Senior Citizen  Partner  Dependents  ...  Tech Support  Streaming TV  \
# 2010               0        1           0  ...             0             0
# 4891               0        1           1  ...             0             0
# 5968               1        1           0  ...             1             0
# 3519               0        1           0  ...             1             0
# 6734               0        0           0  ...             0             0
#
#       Streaming Movies  Contract  Paperless Billing  Payment Method  \
# 2010                 0       0.0                  0        0.333333
# 4891                 1       1.0                  1        0.333333
# 5968                 0       0.0                  1        0.000000
# 3519                 0       1.0                  0        0.333333
# 6734                 0       0.0                  0        0.000000
#
#       Monthly Charges  Total Charges  Churn Value      CLTV
# 2010         0.381592       0.272363            0  0.301534
# 4891         0.721891       0.749250            0  0.930620
# 5968         0.583085       0.491224            0  0.896598
# 3519         0.173632       0.291588            0  0.812097
# 6734         0.018905       0.025312            0  0.393373
#
# [5 rows x 27 columns]

# %%
import pandas as pd

doc = pd.DataFrame(doc) 

X = doc.drop(columns = "Churn Value", axis= "columns")
y= doc["Churn Value"]

# %%
X.shape
# Out:
# (7032, 26)

# %%
from sklearn.model_selection import train_test_split

X_train, X_rem, y_train, y_rem = train_test_split(X, y, train_size= 0.70, random_state=None)
X_valid, X_test, y_valid, y_test = train_test_split(X_rem, y_rem, test_size=0.5)

X_train.shape
# Out:
# (4922, 26)

# %%
import tensorflow
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[222], line 1
# ----> 1 import tensorflow
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
import tensorflow
from tensorflow import keras

model = keras.Sequential([
    keras.layers.Dense(26, input_shape = (26), activation = "relu"),
    keras.layers.Dense(1, activation = "sigmoid")
])

model.compile(optimizer = "adam", loss = "binary_crossentropy", metrics = ["accuracy"])

model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[223], line 1
# ----> 1 import tensorflow
#       2 from tensorflow import keras
#       4 model = keras.Sequential([
#       5     keras.layers.Dense(26, input_shape = (26), activation = "relu"),
#       6     keras.layers.Dense(1, activation = "sigmoid")
#       7 ])
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
model_output = model.predict(X_test)
